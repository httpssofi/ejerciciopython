# %%
import sys
sys.path.append('../src')
from funcionesejer8 import cifrar_mensaje, descifrar_mensaje
mensaje = input("ingrese un mensaje: ")
desplazamiento = int(input("ingrese un desplazamiento: "))
mensaje_cifrado = cifrar_mensaje(mensaje, desplazamiento)
print(f"mensaje cifrado: {mensaje_cifrado}")
mensaje_descifrado = descifrar_mensaje(mensaje_cifrado, desplazamiento)
print(f"mensaje descifrado: {mensaje_descifrado}")
# Out:
# mensaje cifrado: jqnc
# mensaje descifrado: hola
